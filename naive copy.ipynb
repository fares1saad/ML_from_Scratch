# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# %%
def custom_discretize_numerical_column_uniform(column, num_bins=5):
    min_val = column.min()
    max_val = column.max()
    bin_width = (max_val - min_val) / num_bins

    # Assign bin labels based on uniform intervals
    discretized_column = ((column - min_val) / bin_width).astype(int)

    return discretized_column

def discretize_dataframe_uniform(df,threhold=10, num_bins=5):

    for col in df.columns:
        if df[col].dtype == 'object' or len(df[col].unique()) < threhold:
            # Column is categorical or has too many unique values, skip discretization
            continue
        else:
            # Column is numerical and suitable for discretization
            df[col + '_bins'] = custom_discretize_numerical_column_uniform(df[col], num_bins=num_bins)
            df.drop(columns=[col], inplace=True)

    return df

# %%
class NiveBayesClassifier():
    
    def __init__(self, data, label):
        self.data=data
        self.target=label
        self.labels= self.data[label].unique().tolist()
        self.cols= data.columns.tolist()
        v_lab={}
        self.tables={}
        self.label_c={}
        '''
        label_c is a dictionary count of each label in the target 
        tables are dictionaries that holds all the naive bayes tables 
        self.labels is the uniqu val of the target columns 

        '''
    
    #count the target label only 
    def count_labels(self):
        sum=0
        for label in self.labels:
            count = (self.data[self.target] == label).sum()
            self.label_c[str(label)]=count
            sum+=count    
        self.label_c["total"]=sum

        
    #construct table for a column in the data Frame 
    def cons_table(self,col):
        table={}
        uniq_val = self.data[col].unique().tolist()
        for cat in uniq_val:
            sub_table={}
            for label in self.labels:
                val=((self.data[self.target] == label ) & (self.data[col] == cat )).sum()
                sub_table[str(label)]= round(val/self.label_c[str(label)],3)
            table[str(cat)]=sub_table
        return table

    def cons_table_target(self):
        table={}
        for label in self.labels:
            table[str(label)]= self.label_c[str(label)]/self.label_c["total"]
        return table
    
    #for construction of every table including the target table         
    def con_tables(self):
        #unique of the label columns
        #loop over each label
        for col in self.cols:
            if(col==self.target):
                self.tables[col]=self.cons_table_target()

            else:
                self.tables[col]=self.cons_table(col)

    def naive(self):
        self.count_labels()
        self.con_tables()
        print(self.tables)
        print(self.label_c)

    
    def test(self,test):
        correct=0
        for index,row in test.iterrows():
            max=0
            max_label="none"
            for lab in self.labels :
                sum=1
                for col in self.cols:#age
                    if(col!=self.target):#age != depression 
                        cat =str(row[col])#high
                        lb=str(lab)
                        val=self.tables[str(col)][cat][lb]
                        sum*= val
                    else:
                        sum*=self.tables[str(col)][str(lab)]
                
                print("row number : "+ str(index)+ " for label : "+str(lab) + " = "+str(sum))
                #selects the output label
                if(sum>max):
                    max=sum
                    max_label = lab 
            print(max_label)
            if(max_label==row[self.target]):
                correct+=1
        
        return correct/len(test)

# %%
def on_submit():
    data = pd.read_csv("diabetes.csv")
    df=discretize_dataframe_uniform(data)
    training_size = int(training_size_entry.get())
    test_size_1 = int(test_size_entry.get())
    
    total_rows = len(df)
    train_size = int(0.75 * total_rows)  # 75% for training
    test_size = total_rows - train_size  # Remaining 25% for testing

    # Split the DataFrame into training and testing sets
    df_train = df.iloc[:train_size]   # First 75% for training
    df_test = df.iloc[train_size:]   
    
    nb=NiveBayesClassifier(df_train[:training_size],"diabetes")
    nb.naive()
    #print(df_test)
    accuracy=20
    accuracy = nb.test(df_test[:test_size_1])
    result_label.config(text=f"Accuracy: {accuracy:.2f}%")

# Create main application window
root = tk.Tk()
root.title("Accuracy Calculator")

# Create input widgets
training_label = ttk.Label(root, text="Training Set Size:")
training_label.grid(row=0, column=0, padx=10, pady=5, sticky="e")
training_size_entry = ttk.Entry(root, width=10)
training_size_entry.grid(row=0, column=1, padx=10, pady=5)

test_label = ttk.Label(root, text="Test Set Size:")
test_label.grid(row=1, column=0, padx=10, pady=5, sticky="e")
test_size_entry = ttk.Entry(root, width=10)
test_size_entry.grid(row=1, column=1, padx=10, pady=5)

submit_button = ttk.Button(root, text="Calculate Accuracy", command=on_submit)
submit_button.grid(row=2, column=0, columnspan=2, pady=10)

result_label = ttk.Label(root, text="", font=("Helvetica", 12, "bold"))
result_label.grid(row=3, column=0, columnspan=2, pady=10)

# Start the main event loop
root.mainloop()
# Out:
# {'gender': {'Female': {'0': 0.593, '1': 0.537}, 'Male': {'0': 0.407, '1': 0.463}}, 'hypertension': {'0': {'0': 0.943, '1': 0.829}, '1': {'0': 0.057, '1': 0.171}}, 'heart_disease': {'1': {'0': 0.028, '1': 0.073}, '0': {'0': 0.972, '1': 0.927}}, 'smoking_history': {'never': {'0': 0.377, '1': 0.439}, 'No Info': {'0': 0.383, '1': 0.098}, 'current': {'0': 0.061, '1': 0.171}, 'former': {'0': 0.092, '1': 0.171}, 'ever': {'0': 0.039, '1': 0.024}, 'not current': {'0': 0.048, '1': 0.098}}, 'diabetes': {'0': 0.918, '1': 0.082}, 'age_bins': {'5': {'0': 0.054, '1': 0.146}, '3': {'0': 0.2, '1': 0.341}, '1': {'0': 0.233, '1': 0.024}, '2': {'0': 0.227, '1': 0.195}, '4': {'0': 0.113, '1': 0.293}, '0': {'0': 0.172, '1': 0.0}}, 'bmi_bins': {'0': {'0': 0.481, '1': 0.293}, '1': {'0': 0.503, '1': 0.659}, '2': {'0': 0.015, '1': 0.024}, '3': {'0': 0.0, '1': 0.024}}, 'HbA1c_level_bins': {'2': {'0': 0.623, '1': 0.463}, '1': {'0': 0.181, '1': 0.0}, '0': {'0': 0.196, '1': 0.0}, '5': {'0': 0.0, '1': 0.146}, '3': {'0': 0.0, '1': 0.244}, '4': {'0': 0.0, '1': 0.146}}, 'blood_glucose_level_bins': {'1': {'0': 0.641, '1': 0.61}, '0': {'0': 0.279, '1': 0.0}, '2': {'0': 0.081, '1': 0.122}, '4': {'0': 0.0, '1': 0.146}, '3': {'0': 0.0, '1': 0.049}, '5': {'0': 0.0, '1': 0.073}}}
# {'0': 459, '1': 41, 'total': 500}
# row number : 75000 for label : 0 = 0.007341676675152478
# row number : 75000 for label : 1 = 9.357962571686902e-05
# 0
# row number : 75001 for label : 0 = 6.474434257985298e-05
# row number : 75001 for label : 1 = 0.0
# 0
# row number : 75002 for label : 0 = 0.0
# row number : 75002 for label : 1 = 2.1178517160553666e-06
# 1
# row number : 75003 for label : 0 = 0.008202263031108015
# row number : 75003 for label : 1 = 0.00023971763299696484
# 0
# row number : 75004 for label : 0 = 8.559804303356907e-05
# row number : 75004 for label : 1 = 0.0
# 0
# row number : 75005 for label : 0 = 0.00880413442060711
# row number : 75005 for label : 1 = 6.635817070937248e-05
# 0
# row number : 75006 for label : 0 = 0.0017375778379059561
# row number : 75006 for label : 1 = 0.0
# 0
# row number : 75007 for label : 0 = 0.002148489036328525
# row number : 75007 for label : 1 = 2.5847943488161037e-05
# 0
# row number : 75008 for label : 0 = 0.0
# row number : 75008 for label : 1 = 3.7893861478350296e-05
# 1
# row number : 75009 for label : 0 = 0.005269360104244217
# row number : 75009 for label : 1 = 0.00018147040288198202
# 0
# row number : 75010 for label : 0 = 0.008202263031108015
# row number : 75010 for label : 1 = 0.00023971763299696484
# 0
# row number : 75011 for label : 0 = 0.001982252702291169
# row number : 75011 for label : 1 = 4.0066350013674123e-05
# 0
# row number : 75012 for label : 0 = 0.00022549728634606547
# row number : 75012 for label : 1 = 0.0
# 0
# row number : 75013 for label : 0 = 0.0028139223773311073
# row number : 75013 for label : 1 = 0.0
# 0
# row number : 75014 for label : 0 = 0.0011528636724277203
# row number : 75014 for label : 1 = 0.0
# 0
# row number : 75015 for label : 0 = 0.0013633314276187045
# row number : 75015 for label : 1 = 0.0
# 0
# row number : 75016 for label : 0 = 0.00871392915224101
# row number : 75016 for label : 1 = 0.00012035921054063289
# 0
# row number : 75017 for label : 0 = 0.00017995730875629382
# row number : 75017 for label : 1 = 3.216330170468587e-05
# 0
# row number : 75018 for label : 0 = 0.0058870309185524265
# row number : 75018 for label : 1 = 0.0004648624645015282
# 0
# row number : 75019 for label : 0 = 0.001506922728955373
# row number : 75019 for label : 1 = 0.0
# 0
# row number : 75020 for label : 0 = 0.0019863772397491204
# row number : 75020 for label : 1 = 0.0
# 0
# row number : 75021 for label : 0 = 0.00039821256281084003
# row number : 75021 for label : 1 = 0.0
# 0
# row number : 75022 for label : 0 = 0.0012845597302591576
# row number : 75022 for label : 1 = 0.0
# 0
# row number : 75023 for label : 0 = 0.0005636712650063048
# row number : 75023 for label : 1 = 0.0
# 0
# row number : 75024 for label : 0 = 0.0018441965977068885
# row number : 75024 for label : 1 = 0.0003672561970609548
# 0
# row number : 75025 for label : 0 = 4.850976762607346e-05
# row number : 75025 for label : 1 = 2.904020138276823e-05
# 0
# row number : 75026 for label : 0 = 0.0
# row number : 75026 for label : 1 = 0.00022091671856764097
# 1
# row number : 75027 for label : 0 = 0.002445987786898115
# row number : 75027 for label : 1 = 0.0
# 0
# row number : 75028 for label : 0 = 0.0006192525688809935
# row number : 75028 for label : 1 = 0.0
# 0
# row number : 75029 for label : 0 = 0.001205593403806951
# row number : 75029 for label : 1 = 0.0
# 0
# row number : 75030 for label : 0 = 0.0018343585734417894
# row number : 75030 for label : 1 = 0.0
# 0
# row number : 75031 for label : 0 = 0.0006419371772174349
# row number : 75031 for label : 1 = 0.0
# 0
# row number : 75032 for label : 0 = 0.008202263031108015
# row number : 75032 for label : 1 = 0.00023971763299696484
# 0
# row number : 75033 for label : 0 = 0.003722779841042412
# row number : 75033 for label : 1 = 0.0
# 0
# row number : 75034 for label : 0 = 0.00017086137996265755
# row number : 75034 for label : 1 = 0.0
# 0
# row number : 75035 for label : 0 = 0.0018861646244261229
# row number : 75035 for label : 1 = 0.0
# 0
# row number : 75036 for label : 0 = 0.0009708561030854826
# row number : 75036 for label : 1 = 0.0
# 0
# row number : 75037 for label : 0 = 0.007557196927559751
# row number : 75037 for label : 1 = 0.0009428390088290007
# 0
# row number : 75038 for label : 0 = 0.00587030810102348
# row number : 75038 for label : 1 = 5.678646990535278e-06
# 0
# row number : 75039 for label : 0 = 0.0006090031984709407
# row number : 75039 for label : 1 = 2.5413893275709965e-05
# 0
# row number : 75040 for label : 0 = 0.002257598089818534
# row number : 75040 for label : 1 = 0.0
# 0
# row number : 75041 for label : 0 = 0.003733384968901261
# row number : 75041 for label : 1 = 0.0
# 0
# row number : 75042 for label : 0 = 8.541382205460386e-05
# row number : 75042 for label : 1 = 0.0
# 0
# row number : 75043 for label : 0 = 0.0025578624881699625
# row number : 75043 for label : 1 = 0.0
# 0
# row number : 75044 for label : 0 = 0.00660262473209451
# row number : 75044 for label : 1 = 0.0
# 0
# row number : 75045 for label : 0 = 0.0036644595302166827
# row number : 75045 for label : 1 = 0.0
# 0
# row number : 75046 for label : 0 = 0.0017835050054276994
# row number : 75046 for label : 1 = 0.0
# 0
# row number : 75047 for label : 0 = 0.0005726421604705962
# row number : 75047 for label : 1 = 0.0
# 0
# row number : 75048 for label : 0 = 0.0010719231323094692
# row number : 75048 for label : 1 = 6.586249317316294e-06
# 0
# row number : 75049 for label : 0 = 0.008419062935013955
# row number : 75049 for label : 1 = 2.9503708676549523e-05
# 0
# row number : 75050 for label : 0 = 0.002630101774638592
# row number : 75050 for label : 1 = 0.0
# 0
# row number : 75051 for label : 0 = 0.002671960158319843
# row number : 75051 for label : 1 = 0.0
# 0
# row number : 75052 for label : 0 = 3.818880541248441e-06
# row number : 75052 for label : 1 = 0.0
# 0
# row number : 75053 for label : 0 = 0.007557196927559751
# row number : 75053 for label : 1 = 0.0009428390088290007
# 0
# row number : 75054 for label : 0 = 0.0006192525688809935
# row number : 75054 for label : 1 = 0.0
# 0
# row number : 75055 for label : 0 = 0.0017375778379059561
# row number : 75055 for label : 1 = 0.0
# 0
# row number : 75056 for label : 0 = 2.840586871595609e-05
# row number : 75056 for label : 1 = 6.594500379584832e-06
# 0
# row number : 75057 for label : 0 = 0.0029771884588979825
# row number : 75057 for label : 1 = 0.00015592618194844784
# 0
# row number : 75058 for label : 0 = 0.005778345049832513
# row number : 75058 for label : 1 = 2.543802070249987e-05
# 0
# row number : 75059 for label : 0 = 0.007557196927559751
# row number : 75059 for label : 1 = 0.0009428390088290007
# 0
# row number : 75060 for label : 0 = 0.0007423310006525336
# row number : 75060 for label : 1 = 0.0
# 0
# row number : 75061 for label : 0 = 0.0019511991351534486
# row number : 75061 for label : 1 = 0.00017948089444900952
# 0
# row number : 75062 for label : 0 = 0.0
# row number : 75062 for label : 1 = 1.3089344312053931e-05
# 1
# row number : 75063 for label : 0 = 0.002230533197411449
# row number : 75063 for label : 1 = 0.0
# 0
# row number : 75064 for label : 0 = 0.0059807237183171855
# row number : 75064 for label : 1 = 0.00010377339754248238
# 0
# row number : 75065 for label : 0 = 0.0058870309185524265
# row number : 75065 for label : 1 = 0.0004648624645015282
# 0
# row number : 75066 for label : 0 = 0.0003964204911532708
# row number : 75066 for label : 1 = 0.0
# 0
# row number : 75067 for label : 0 = 0.0
# row number : 75067 for label : 1 = 2.9576003886064996e-05
# 1
# row number : 75068 for label : 0 = 0.008577418512780316
# row number : 75068 for label : 1 = 0.0005391601370136514
# 0
# row number : 75069 for label : 0 = 0.00433344632350231
# row number : 75069 for label : 1 = 0.0
# 0
# row number : 75070 for label : 0 = 0.002748146492099978
# row number : 75070 for label : 1 = 0.0
# 0
# row number : 75071 for label : 0 = 0.0
# row number : 75071 for label : 1 = 2.3509310843685937e-05
# 1
# row number : 75072 for label : 0 = 6.987439020512075e-07
# row number : 75072 for label : 1 = 0.0
# 0
# row number : 75073 for label : 0 = 0.00012150497380383802
# row number : 75073 for label : 1 = 0.0
# 0
# row number : 75074 for label : 0 = 0.0008645854132449369
# row number : 75074 for label : 1 = 0.0
# 0
# row number : 75075 for label : 0 = 0.003733384968901261
# row number : 75075 for label : 1 = 0.0
# 0
# row number : 75076 for label : 0 = 0.0012589948387703343
# row number : 75076 for label : 1 = 0.0
# 0
# row number : 75077 for label : 0 = 0.0002597911728943617
# row number : 75077 for label : 1 = 9.011510122529436e-05
# 0
# row number : 75078 for label : 0 = 0.0006241998644870996
# row number : 75078 for label : 1 = 0.0
# 0
# row number : 75079 for label : 0 = 0.006499189357701385
# row number : 75079 for label : 1 = 0.0
# 0
# row number : 75080 for label : 0 = 3.2360132431165817e-06
# row number : 75080 for label : 1 = 0.0
# 0
# row number : 75081 for label : 0 = 0.0011231761958845172
# row number : 75081 for label : 1 = 0.0
# 0
# row number : 75082 for label : 0 = 0.0007675920738150403
# row number : 75082 for label : 1 = 0.0
# 0
# row number : 75083 for label : 0 = 0.008577418512780316
# row number : 75083 for label : 1 = 0.0005391601370136514
# 0
# row number : 75084 for label : 0 = 0.0018584691695411565
# row number : 75084 for label : 1 = 0.0
# 0
# row number : 75085 for label : 0 = 0.00030522013292510987
# row number : 75085 for label : 1 = 0.0
# 0
# row number : 75086 for label : 0 = 0.00136223564730995
# row number : 75086 for label : 1 = 1.1492332992460067e-05
# 0
# row number : 75087 for label : 0 = 0.00022537270739413987
# row number : 75087 for label : 1 = 0.0
# 0
# row number : 75088 for label : 0 = 0.002230533197411449
# row number : 75088 for label : 1 = 0.0
# 0
# row number : 75089 for label : 0 = 0.0019511991351534486
# row number : 75089 for label : 1 = 0.00017948089444900952
# 0
# row number : 75090 for label : 0 = 0.0007418018037174757
# row number : 75090 for label : 1 = 1.1357293981070558e-06
# 0
# row number : 75091 for label : 0 = 1.7861301015347333e-05
# row number : 75091 for label : 1 = 0.0
# 0
# row number : 75092 for label : 0 = 0.0
# row number : 75092 for label : 1 = 3.335559337045128e-07
# 1
# row number : 75093 for label : 0 = 0.003832064747814951
# row number : 75093 for label : 1 = 0.0
# 0
# row number : 75094 for label : 0 = 0.006313841940631132
# row number : 75094 for label : 1 = 0.0
# 0
# row number : 75095 for label : 0 = 0.0036644595302166827
# row number : 75095 for label : 1 = 0.0
# 0
# row number : 75096 for label : 0 = 0.0005365666946880535
# row number : 75096 for label : 1 = 4.4441731318036406e-05
# 0
# row number : 75097 for label : 0 = 0.000928393211896853
# row number : 75097 for label : 1 = 0.0
# 0
# row number : 75098 for label : 0 = 0.00019004624107779795
# row number : 75098 for label : 1 = 0.0
# 0
# row number : 75099 for label : 0 = 0.0058870309185524265
# row number : 75099 for label : 1 = 0.0004648624645015282
# 0
